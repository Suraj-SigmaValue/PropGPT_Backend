# %%
import sys
from pathlib import Path

# This should be the folder that CONTAINS the "core" package folder
PROJECT_ROOT = Path(r"D:\PropGPT\PropGPT_Backend")
sys.path.insert(0, str(PROJECT_ROOT))

# %%
from core.graph_agent import create_graph

app = create_graph()
#app.get_graph().draw_mermaid()

# %%
#

app
# Out:
# 2026-01-13 13:01:45,924 - DEBUG - Starting new HTTPS connection (1): mermaid.ink:443
# 2026-01-13 13:01:47,031 - DEBUG - https://mermaid.ink:443 "GET ...?type=png&bgColor=%21white HTTP/1.1" 200 22965
